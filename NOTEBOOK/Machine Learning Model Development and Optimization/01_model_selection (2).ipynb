# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv("../../DATA/featured_telco.csv")

# %%
df.head()
# Out:
#      Gender  Senior Citizen   Partner  Dependents  Tenure Months  \
# 0  0.990658       -0.440327 -0.965608   -0.547115      -1.239504
# 1 -1.009430       -0.440327 -0.965608    1.827769      -1.239504
# 2 -1.009430       -0.440327 -0.965608    1.827769      -0.995040
# 3 -1.009430       -0.440327  1.035617    1.827769      -0.180161
# 4  0.990658       -0.440327 -0.965608    1.827769       0.675462
#
#    Phone Service  Multiple Lines  Online Security  Online Backup  \
# 0       0.327189       -0.991564         1.408012       1.242875
# 1       0.327189       -0.991564        -0.917837      -1.028998
# 2       0.327189        1.116896        -0.917837      -1.028998
# 3       0.327189        1.116896        -0.917837      -1.028998
# 4       0.327189        1.116896        -0.917837       1.242875
#
#    Device Protection  ...  Payment Method_Credit card (automatic)  \
# 0          -1.026988  ...                                       0
# ...

# %% [markdown]
# Is the dataset ready for machine learning?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Gender                                    7032 non-null   float64
#  1   Senior Citizen                            7032 non-null   float64
#  2   Partner                                   7032 non-null   float64
#  3   Dependents                                7032 non-null   float64
#  4   Tenure Months                             7032 non-null   float64
#  5   Phone Service                             7032 non-null   float64
#  6   Multiple Lines                            7032 non-null   float64
#  7   Online Security                           7032 non-null   float64
#  8   Online Backup                             7032 non-null   float64
#  9   Device Protection                         7032 non-null   float64
# ...

# %% [markdown]
# Which column should be used as the target variable?

# %%
df.columns
# Out:
# Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Paperless Billing', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'CLTV', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'Payment Method_Bank transfer (automatic)',
#        'Payment Method_Credit card (automatic)',
#        'Payment Method_Electronic check', 'Payment Method_Mailed check',
#        'Internet Service_DSL', 'Internet Service_Fiber optic',
#        'Internet Service_No', 'Average Charges', 'CLTV per Month',
#        'High Monthly Charge', 'Loyal Customer'],
#       dtype='object')

# %%
target = "Churn Label"

print(target)
# Out:
# Churn Label

# %% [markdown]
# "Churn Label" is the target variable that the model will learn to predict.

# %% [markdown]
# Which columns will be used as input features?

# %%
X = df.drop(columns=["Churn Label"])

y = df["Churn Label"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (7032, 31)
# (7032,)

# %% [markdown]
# The dataset has been successfully divided into features (X) and target (y).

# %% [markdown]
# Which machine learning models are suitable for churn prediction?

# %%
models = {
    "Logistic Regression": LogisticRegression(random_state=42),

    "Decision Tree": DecisionTreeClassifier(random_state=42),

    "Random Forest": RandomForestClassifier(random_state=42),

    "Gradient Boosting": GradientBoostingClassifier(random_state=42)
}

# %%
models
# Out:
# {'Logistic Regression': LogisticRegression(random_state=42),
#  'Decision Tree': DecisionTreeClassifier(random_state=42),
#  'Random Forest': RandomForestClassifier(random_state=42),
#  'Gradient Boosting': GradientBoostingClassifier(random_state=42)}

# %% [markdown]
# Why were these models selected?
#
# Logistic Regression
#
# Suitable for binary classification and provides a simple baseline model.
#
# Decision Tree
#
# Easy to interpret and captures non-linear relationships.
#
# Random Forest
#
# Combines multiple decision trees to improve prediction accuracy and reduce overfitting.
#
# Gradient Boosting
#
# Builds strong predictive models by sequentially correcting previous errors.

# %% [markdown]
# Are these models appropriate for binary classification?
#
# The project objective is to predict whether a customer will churn or not.

# %%
print(df["Churn Label"].unique())
# Out:
# [1 0]

# %% [markdown]
# The target variable contains only two classes.
#
# Therefore, the selected algorithms are appropriate for binary classification.

# %% [markdown]
# The selected models are now ready for training.
#
# The selected machine learning models will be trained and evaluated in the next notebook.

# %% [markdown]
# ## Conclusion
#
# Four classification algorithms were selected for customer churn prediction.
#
# The dataset was successfully prepared by separating the input features (X) and the target variable (y).
#
# These models will be trained and evaluated in the next stage.
