# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../DATA/processed_telco.csv")

# %%
df.head()
# Out:
#      Gender  Senior Citizen   Partner  Dependents  Tenure Months  \
# 0  0.990658       -0.440327 -0.965608   -0.547115      -1.239504
# 1 -1.009430       -0.440327 -0.965608    1.827769      -1.239504
# 2 -1.009430       -0.440327 -0.965608    1.827769      -0.995040
# 3 -1.009430       -0.440327  1.035617    1.827769      -0.180161
# 4  0.990658       -0.440327 -0.965608    1.827769       0.675462
#
#    Phone Service  Multiple Lines  Online Security  Online Backup  \
# 0       0.327189       -0.991564         1.408012       1.242875
# 1       0.327189       -0.991564        -0.917837      -1.028998
# 2       0.327189        1.116896        -0.917837      -1.028998
# 3       0.327189        1.116896        -0.917837      -1.028998
# 4       0.327189        1.116896        -0.917837       1.242875
#
#    Device Protection  ...  Contract_One year  Contract_Two year  \
# 0          -1.026988  ...              False              False
# 1          -1.026988  ...              False              False
# 2           1.245441  ...              False              False
# 3           1.245441  ...              False              False
# 4           1.245441  ...              False              False
#
#    Payment Method_Bank transfer (automatic)  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                      True
#
#    Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                   False                            False
# 1                                   False                             True
# 2                                   False                             True
# 3                                   False                             True
# 4                                   False                            False
#
#    Payment Method_Mailed check  Internet Service_DSL  \
# 0                         True                  True
# 1                        False                 False
# 2                        False                 False
# 3                        False                 False
# 4                        False                 False
#
#    Internet Service_Fiber optic  Internet Service_No  Average Charges
# 0                         False                False         4.006817
# 1                          True                False         3.926687
# 2                          True                False      -130.122842
# 3                          True                False         0.410465
# 4                          True                False         0.724928
#
# [5 rows x 29 columns]

# %% [markdown]
# Are there any opportunities to create new features?

# %%
df.columns
# Out:
# Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Paperless Billing', 'Monthly Charges', 'Total Charges', 'Churn Label',
#        'CLTV', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'Payment Method_Bank transfer (automatic)',
#        'Payment Method_Credit card (automatic)',
#        'Payment Method_Electronic check', 'Payment Method_Mailed check',
#        'Internet Service_DSL', 'Internet Service_Fiber optic',
#        'Internet Service_No', 'Average Charges'],
#       dtype='object')

# %% [markdown]
# Can we calculate the average monthly spending for each customer?

# %%
df["Average Charges"] = (
    df["Total Charges"] /
    (df["Tenure Months"] + 1)
)

# %% [markdown]
# Does the new feature look reasonable?

# %%
df["Average Charges"].describe()
# Out:
# count    7032.000000
# mean       -2.011540
# std        22.031629
# min      -191.990773
# 25%        -0.450478
# 50%         0.340080
# 75%         0.941223
# max        26.957560
# Name: Average Charges, dtype: float64

# %% [markdown]
# Are all features already encoded?

# %%
df.select_dtypes(include="object").columns
# Out:
# Index([], dtype='object')

# max       1.000000  1.774931e+00        26.957560

# %% [markdown]
# Do we still have boolean columns?

# %%
bool_columns = df.select_dtypes(include="bool").columns

bool_columns
# Out:
# Index(['Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
#        'Payment Method_Bank transfer (automatic)',
#        'Payment Method_Credit card (automatic)',
#        'Payment Method_Electronic check', 'Payment Method_Mailed check',
#        'Internet Service_DSL', 'Internet Service_Fiber optic',
#        'Internet Service_No'],
#       dtype='object')

# %% [markdown]
# Can we convert boolean features into integers?

# %%
df[bool_columns] = df[bool_columns].astype(int)

# %%
df.dtypes
# Out:
# Gender                                      float64
# Senior Citizen                              float64
# Partner                                     float64
# Dependents                                  float64
# Tenure Months                               float64
# Phone Service                               float64
# Multiple Lines                              float64
# Online Security                             float64
# Online Backup                               float64
# Device Protection                           float64
# Tech Support                                float64
# Streaming TV                                float64
# Streaming Movies                            float64
# Paperless Billing                           float64
# Monthly Charges                             float64
# Total Charges                               float64
# Churn Label                                   int64
# CLTV                                        float64
# Contract_Month-to-month                       int64
# Contract_One year                             int64
# Contract_Two year                             int64
# Payment Method_Bank transfer (automatic)      int64
# Payment Method_Credit card (automatic)        int64
# Payment Method_Electronic check               int64
# Payment Method_Mailed check                   int64
# Internet Service_DSL                          int64
# Internet Service_Fiber optic                  int64
# Internet Service_No                           int64
# Average Charges                             float64
# dtype: object

# %% [markdown]
# Is the dataset ready for machine learning?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Gender                                    7032 non-null   float64
#  1   Senior Citizen                            7032 non-null   float64
#  2   Partner                                   7032 non-null   float64
#  3   Dependents                                7032 non-null   float64
#  4   Tenure Months                             7032 non-null   float64
#  5   Phone Service                             7032 non-null   float64
#  6   Multiple Lines                            7032 non-null   float64
#  7   Online Security                           7032 non-null   float64
#  8   Online Backup                             7032 non-null   float64
#  9   Device Protection                         7032 non-null   float64
#  10  Tech Support                              7032 non-null   float64
#  11  Streaming TV                              7032 non-null   float64
#  12  Streaming Movies                          7032 non-null   float64
#  13  Paperless Billing                         7032 non-null   float64
#  14  Monthly Charges                           7032 non-null   float64
#  15  Total Charges                             7032 non-null   float64
#  16  Churn Label                               7032 non-null   int64
#  17  CLTV                                      7032 non-null   float64
#  18  Contract_Month-to-month                   7032 non-null   int64
#  19  Contract_One year                         7032 non-null   int64
#  20  Contract_Two year                         7032 non-null   int64
#  21  Payment Method_Bank transfer (automatic)  7032 non-null   int64
#  22  Payment Method_Credit card (automatic)    7032 non-null   int64
#  23  Payment Method_Electronic check           7032 non-null   int64
#  24  Payment Method_Mailed check               7032 non-null   int64
#  25  Internet Service_DSL                      7032 non-null   int64
#  26  Internet Service_Fiber optic              7032 non-null   int64
#  27  Internet Service_No                       7032 non-null   int64
#  28  Average Charges                           7032 non-null   float64
# dtypes: float64(18), int64(11)
# memory usage: 1.6 MB

# %% [markdown]
# Can we estimate the customer's value per month?

# %%
df["CLTV per Month"] = df["CLTV"] / (df["Tenure Months"] + 1)

# %%
df[["CLTV","Tenure Months","CLTV per Month"]].head()
# Out:
#        CLTV  Tenure Months  CLTV per Month
# 0 -0.983181      -1.239504        4.105072
# 1 -1.438215      -1.239504        6.004971
# 2  0.820883      -0.995040      165.510906
# 3  0.508788      -0.180161        0.620595
# 4  0.793818       0.675462        0.473790

# %% [markdown]
# Can we identify high-paying customers?

# %%
median_charge = df["Monthly Charges"].median()

df["High Monthly Charge"] = np.where(
    df["Monthly Charges"] > median_charge,
    1,
    0
)

# %%
df["High Monthly Charge"].value_counts()
# Out:
# High Monthly Charge
# 0    3519
# 1    3513
# Name: count, dtype: int64

# %% [markdown]
# Can we identify loyal customers?

# %%
median_tenure = df["Tenure Months"].median()

df["Loyal Customer"] = np.where(
    df["Tenure Months"] > median_tenure,
    1,
    0
)

# %%
df["Loyal Customer"].value_counts()
# Out:
# Loyal Customer
# 0    3558
# 1    3474
# Name: count, dtype: int64

# %% [markdown]
# How many new engineered features were created?

# %%
new_features = [
    "Average Charges",
    "CLTV per Month",
    "High Monthly Charge",
    "Loyal Customer"
]

df[new_features].head()
# Out:
#    Average Charges  CLTV per Month  High Monthly Charge  Loyal Customer
# 0         4.006817        4.105072                    0               0
# 1         3.926687        6.004971                    1               0
# 2      -130.122842      165.510906                    1               0
# 3         0.410465        0.620595                    1               0
# 4         0.724928        0.473790                    1               1

# %% [markdown]
# Can we save the feature engineered dataset?

# %%
df.to_csv("../../DATA/featured_telco.csv", index=False)

# %% [markdown]
# Key Insights (تكتبيها آخر الـ Notebook)
# A new feature (Average Charges) was created to better represent customer spending behavior.
# All categorical variables were already encoded during preprocessing.
# Numerical features were already standardized using feature scaling.
# Boolean columns were converted into integer values.
# The final dataset contains only numerical features and is fully prepared for machine learning models.

# %% [markdown]
# Key Insights
# Created Average Charges to represent customer monthly spending.
# Created CLTV per Month to estimate customer value over time.
# Created Service Count to summarize the number of subscribed services.
# Created Has Many Services to classify customers based on service usage.
# Created High Monthly Charge to distinguish high-paying customers.
# Created Loyal Customer based on customer tenure.
# The dataset now contains richer behavioral features that can improve churn predictio

# %%
df.columns.tolist()
# Out:
# ['Gender',
#  'Senior Citizen',
#  'Partner',
#  'Dependents',
#  'Tenure Months',
#  'Phone Service',
#  'Multiple Lines',
#  'Online Security',
#  'Online Backup',
#  'Device Protection',
#  'Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Paperless Billing',
#  'Monthly Charges',
#  'Total Charges',
#  'Churn Label',
#  'CLTV',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'Payment Method_Bank transfer (automatic)',
#  'Payment Method_Credit card (automatic)',
#  'Payment Method_Electronic check',
#  'Payment Method_Mailed check',
#  'Internet Service_DSL',
#  'Internet Service_Fiber optic',
#  'Internet Service_No',
#  'Average Charges',
#  'CLTV per Month',
#  'High Monthly Charge',
#  'Loyal Customer']
